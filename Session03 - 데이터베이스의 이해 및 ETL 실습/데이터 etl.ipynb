# %%
### 1. 상대경로/ 절대경로
### 2. 데이터 불러오기 (pandas ~ csv ~ sep의 활용 기억. 기본적으로 ","로 분리하도록 설정돼있음)
### 3. 데이터 불러올 경우 한글 유의

# %% [markdown]
# ## 1.라이브러리 정의

# %%
import pandas as pd

# %% [markdown]
# ## 2.데이터 불러오기

# %%
pd.read_csv("../dataset/customerdata.csv")
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2            6    0.900000        Early-bird
# 4    B10634  3391.074215    2            4    2.453656      Sleeping-dog
# ..      ...          ...  ...          ...         ...               ...
# 145  Z13253  3678.800000    2            5    2.463670  Big-Screen-lover
# 146  Z13534  3662.437527    3            6    0.900000        Early-bird
# 147  Z16428  3516.500000    2            5    2.371301  Big-Screen-lover
# 148  Z16735  3300.100000    2            5    1.704942  Big-Screen-lover
# 149  Z19835  3326.526183    2            6    1.200000        Early-bird
#
# [150 rows x 6 columns]

# %%
indata = pd.read_csv("./currData.csv")

# %%
indata.to_csv("./outData.csv", index = True) # 인덱스 포함해서 저장. 인덱스 없애려면 false

# %%
# 한글 처리에 대한 문제 
pd.read_csv("../dataset/kopo_region_mst_hangul.csv")
# Out:
#    REGIONID REGIONNAME
# 0       A00    ������ī
# 1       A01        �̱�
# 2       A02        �ѱ�
# 3       A03       ����
# 4       A04      �����
# ..      ...        ...
# 68      A68  ���׼�����
# 69      A69      ��Ʈ��
# 70      A70    �ٴ�����
# 71      A71        NaN
# 72      A99        ��Ÿ
#
# [73 rows x 2 columns]

# %%
# ms949 라는 키를 쓰자 ! 
data = pd.read_csv("../dataset/kopo_region_mst_hangul.csv",
           encoding ="ms949")

# %%
data
# Out:
#    REGIONID REGIONNAME
# 0       A00       아프리카
# 1       A01         미국
# 2       A02         한국
# 3       A03         독일
# 4       A04        브라질
# ..      ...        ...
# 68      A68      베네수엘라
# 69      A69        베트남
# 70      A70       바누아투
# 71      A71        NaN
# 72      A99         기타
#
# [73 rows x 2 columns]

# %%
data.to_csv("./hangul.csv")
# csv 로 바꿀때 에러 생김

data.to_csv("./hangul.csv",
           encoding = "ms949",
           index = False)
# 데이터 저장 시 TRY EXCEPT가 있는 거 알기

# %% [markdown]
# ## 3. 데이터 변환( 컬럼 이름 변경)

# %%
#데이터 컬럼 재정의 
data.columns =["SALESID","REGIONNAME"]

# %%
data.rename(columns ={})
# Out:
#    SALESID REGIONNAME
# 0      A00       아프리카
# 1      A01         미국
# 2      A02         한국
# 3      A03         독일
# 4      A04        브라질
# ..     ...        ...
# 68     A68      베네수엘라
# 69     A69        베트남
# 70     A70       바누아투
# 71     A71        NaN
# 72     A99         기타
#
# [73 rows x 2 columns]

# %%
data.rename(columns ={"SAILESID" :"SID", "REGIONNAME": "SNAME"})
# 바꾼 것 처럼 보이는데 data 찍어보면 바뀐게 아님 

data.rename(columns ={"SAILESID" :"SID", "REGIONNAME": "SNAME"}, inplace = True)
# 위처럼 inplace 해줘야됨 -> 변경 결과 즉시 적용
# Out:
#    SALESID  SNAME
# 0      A00   아프리카
# 1      A01     미국
# 2      A02     한국
# 3      A03     독일
# 4      A04    브라질
# ..     ...    ...
# 68     A68  베네수엘라
# 69     A69    베트남
# 70     A70   바누아투
# 71     A71    NaN
# 72     A99     기타
#
# [73 rows x 2 columns]

# %%
engine = create_engine(“postgresql://postgres:postgres@127.0.0.1:5432/postgres”)
# 예전에 시험에도 나옴 !! (아이디, 패스워드, ip주소, 포트, db이름 )

# %%
import pandas as pd # 활용 라이브러리 (pandas)

# %%
targetData = "../dataset/kopo_product_volume.csv"

# %%
targetData
# Out:
# '../dataset/kopo_product_volume.csv'

# %%
2. 데이터 변환 (컬럼이름 소문자로 변경)

# %%
data.columns = ["regionid", "productgroup","yearweek","volume"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-73e9fef6f450> in <module>
# ----> 1 data.columns = ["regionid", "productgroup","yearweek","volume"]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ...

# %%
3. 데이터 저장(postgres에 저장)

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
mylocalpgUrl = "postgresql://postgres:1234@127.0.0.1/postgres"

# %%
selloutData = pd.read_csv("../dataset/kopo_product_volume.csv")

# %%
selloutData
# Out:
#     regionid productgroup  yearweek  volume
# 0        A01       ST0001    201415  810144
# 1        A01       ST0002    201415  128999
# 2        A01       ST0001    201418  671464
# 3        A01       ST0002    201418  134467
# 4        A01       ST0001    201413  470040
# ..       ...          ...       ...     ...
# 260      A01       ST0002    201614  148835
# 261      A01       ST0001    201641  746061
# 262      A01       ST0002    201412  151750
# 263      A01       ST0001    201420  645626
# 264      A01       ST0002    201420  125863
#
# [265 rows x 4 columns]

# %%
selloutData.columns = ["regionid","productgroup","yearweek","volume"]

# %%
engine_pg = create_engine(mylocalpgUrl)

# %%
resultTableName = "pg_out" #sql안에 pg_out 파일 생성됨

# %%
selloutData.to_sql(name=resultTableName,
           con = mylocalpgUrl,
           if_exists="replace",
           index = False)

# %%
pd.read_sql(sql = "select* from pg_out", con=engine_pg) #sql에 저장햇으니까 sql 로 불러
# Out:
#     regionid productgroup  yearweek  volume
# 0        A01       ST0001    201415  810144
# 1        A01       ST0002    201415  128999
# 2        A01       ST0001    201418  671464
# 3        A01       ST0002    201418  134467
# 4        A01       ST0001    201413  470040
# ..       ...          ...       ...     ...
# 260      A01       ST0002    201614  148835
# 261      A01       ST0001    201641  746061
# 262      A01       ST0002    201412  151750
# 263      A01       ST0001    201420  645626
# 264      A01       ST0002    201420  125863
#
# [265 rows x 4 columns]

# %%
sqlReadData = pd.read_sql(sql = "select* from pg_out where 1=1 and year", con=engine_pg)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedColumn: 오류:  "year" 이름의 칼럼은 없습니다
# LINE 1: select* from pg_out where 1=1 and year
#                                           ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pd.read_sql_table(table_name = "pg_out",con= engine_pg)
# Out:
#     regionid productgroup  yearweek  volume
# 0        A01       ST0001    201415  810144
# 1        A01       ST0002    201415  128999
# 2        A01       ST0001    201418  671464
# 3        A01       ST0002    201418  134467
# 4        A01       ST0001    201413  470040
# ..       ...          ...       ...     ...
# 260      A01       ST0002    201614  148835
# 261      A01       ST0001    201641  746061
# 262      A01       ST0002    201412  151750
# 263      A01       ST0001    201420  645626
# 264      A01       ST0002    201420  125863
#
# [265 rows x 4 columns]

# %%
import psycopg2

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
ehlocalpgUrl = "postgresql://postgres:postgres@192.168.110.14:5432/postgres"

# %%
engine = create_engine(ehlocalpgUrl)

# %%
selloutData = pd.read_sql_query('select*from pg_out', engine)

# %%
selloutData.columns = ["regionid","productgroup","yearweek","volume"]

# %%
eh = selloutData

# %%
eh.to_sql(name = "pg_out_eh", con = engine_pg, index= False)

# %%
못생긴애들 소개시켜줄게  , , ,
제발 , ,

# %% [markdown]
# ## 1.라이브러리 선언하기

# %%
# 데이터 조작 라이브러리

import pandas as pd

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## 2. 데이터 불러오기

# %%
pwd
# Out:
# 'C:\\Users\\SMART-24\\coding\\stddev\\Session03 - 데이터베이스의 이해 및 ETL 실습'

# %%
indata = pd.read_csv("../dataset/kopo_decision_tree_all_new.csv")
indata
# Out:
#       REGIONID PRODUCTGROUP PRODUCT     ITEM  YEARWEEK  YEAR  WEEK  QTY  \
# 0          A01         PG01     P01  ITEM001    201538  2015    38    1
# 1          A01         PG01     P01  ITEM001    201548  2015    48    1
# 2          A01         PG01     P01  ITEM001    201549  2015    49    2
# 3          A01         PG01     P01  ITEM002    201526  2015    26    1
# 4          A01         PG01     P01  ITEM002    201532  2015    32    1
# ...        ...          ...     ...      ...       ...   ...   ...  ...
# 32410      A01         PG05     P16  ITEM491    201503  2015     3    1
# 32411      A01         PG05     P16  ITEM491    201504  2015     4    1
# 32412      A01         PG05     P16  ITEM491    201505  2015     5    2
# 32413      A01         PG05     P16  ITEM491    201506  2015     6    1
# 32414      A01         PG05     P16  ITEM491    201508  2015     8    1
#
#       HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0           N      4         N          0.0
# ...

# %%
# indata 형태보기 
indata.shape
# Out:
# (32415, 12)

# %%
indata.columns
# Out:
# Index(['REGIONID', 'PRODUCTGROUP', 'PRODUCT', 'ITEM', 'YEARWEEK', 'YEAR',
#        'WEEK', 'QTY', 'HOLIDAY', 'HCLUS', 'PROMOTION', 'PRO_PERCENT'],
#       dtype='object')

# %% [markdown]
# ## 3. 데이터 처리(소문자로)

# %%
# 소문자로 바꾸기
indata.columns = indata.columns.str.lower()

# %% [markdown]
# ## 4. 데이터 저장하기

# %%
import pandas as pd

# %%
indata = pd.read_csv("../dataset/kopo_decision_tree_all_new.csv")
indata
# Out:
#       REGIONID PRODUCTGROUP PRODUCT     ITEM  YEARWEEK  YEAR  WEEK  QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0          A01         PG01     P01  ITEM001    201538  2015    38    1       N      4         N          0.0
# 1          A01         PG01     P01  ITEM001    201548  2015    48    1       Y      0         N          0.0
# 2          A01         PG01     P01  ITEM001    201549  2015    49    2       Y      0         N          0.0
# 3          A01         PG01     P01  ITEM002    201526  2015    26    1       Y      1         N          0.0
# 4          A01         PG01     P01  ITEM002    201532  2015    32    1       N      4         N          0.0
# ...        ...          ...     ...      ...       ...   ...   ...  ...     ...    ...       ...          ...
# 32410      A01         PG05     P16  ITEM491    201503  2015     3    1       N      4         N          0.0
# ...

# %%
import psycopg2

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
indata.columns = indata.columns.str.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-39edac15a321> in <module>
# ----> 1 indata.columns = indata.columns.str.lower()
#
# NameError: name 'indata' is not defined

# %%
targetDbIp = "192.168.110.111"
targetDbPort = "5432"
targetDbId = "kopo"
targetDbPw = "kopo"
targetDbName = "kopodb"


targetDbPrefix =  "postgresql+psycopg2://"

targetUrl = "{}{}:{}@{}:{}/{}".format(targetDbPrefix,
                                   targetDbId,
                                   targetDbPw,
                                   targetDbIp,
                                   targetDbPort, 
                                   targetDbName)



pg_kopo_engine=create_engine(targetUrl)

tableName ="pgout_kopo_hj"

# %%
indata = pd.read_csv("../dataset/kopo_decision_tree_all_new.csv")
indata
# Out:
#       REGIONID PRODUCTGROUP PRODUCT     ITEM  YEARWEEK  YEAR  WEEK  QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0          A01         PG01     P01  ITEM001    201538  2015    38    1       N      4         N          0.0
# 1          A01         PG01     P01  ITEM001    201548  2015    48    1       Y      0         N          0.0
# 2          A01         PG01     P01  ITEM001    201549  2015    49    2       Y      0         N          0.0
# 3          A01         PG01     P01  ITEM002    201526  2015    26    1       Y      1         N          0.0
# 4          A01         PG01     P01  ITEM002    201532  2015    32    1       N      4         N          0.0
# ...        ...          ...     ...      ...       ...   ...   ...  ...     ...    ...       ...          ...
# 32410      A01         PG05     P16  ITEM491    201503  2015     3    1       N      4         N          0.0
# ...

# %%
import d6tstack
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-79bc5eaf8112> in <module>
# ----> 1 import d6tstack
#
# ~\anaconda3\lib\site-packages\d6tstack\__init__.py in <module>
# ----> 1 import d6tstack.combine_csv
#       2 #import d6tstack.convert_xls
#       3 import d6tstack.sniffer
#       4 #import d6tstack.sync
#       5 import d6tstack.utils
#
# ~\anaconda3\lib\site-packages\d6tstack\combine_csv.py in <module>
#       2 import pandas as pd
#       3 pd.set_option('display.expand_frame_repr', False)
# ----> 4 from scipy.stats import mode
#       5 import warnings
#       6 import ntpath, pathlib
#
# ImportError: cannot import name 'mode' from 'scipy.stats' (unknown location)

# %%
# !pip show scipy
# Out:
# Name: scipy
# Version: 1.6.1
# Summary: SciPy: Scientific Library for Python
# Home-page: https://www.scipy.org
# Author: None
# Author-email: None
# License: BSD
# Location: c:\users\smart-24\anaconda3\lib\site-packages
# Requires: numpy
# Required-by: statsmodels, seaborn, scikit-learn, scikit-image, d6tstack

# %%
# !pip show numpy
# Out:
# Name: numpy
# Version: 1.18.5
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: c:\users\smart-24\anaconda3\lib\site-packages
# Requires:
# Required-by: tables, statsmodels, seaborn, scipy, scikit-learn, PyWavelets, patsy, pandas, numexpr, numba, mkl-random, mkl-fft, matplotlib, imageio, h5py, d6tstack, Bottleneck, bokeh, bkcharts, astropy

# %%
# !pip show d6tstack
# Out:
# Name: d6tstack
# Version: 0.2.0
# Summary: d6tstack: Quickly ingest CSV and XLS files. Export to pandas, SQL, parquet
# Home-page: https://github.com/d6t/d6tstack
# Author: DataBolt Team
# Author-email: support@databolt.tech
# License: MIT
# Location: c:\users\smart-24\anaconda3\lib\site-packages
# Requires: scipy, sqlalchemy, pandas, numpy, d6tcollect
# Required-by:

# %%
import pandas as pd

import psycopg2
from sqlalchemy import create_engine

indata=pd.read_csv("../dataset/kopo_decision_tree_all_new.csv")
indata.columns=indata.columns.str.lower()

indata

targetDbIp= "192.168.110.111"
targetDbport = "5432"
targetDbId = "kopo"
targetDbPw= "kopo"
targetDbName = "kopodb"

targetDbPrefix =  "postgresql+psycopg2://"

targetUrl = "{}{}:{}@{}:{}/{}".format(targetDbPrefix,
                                     targetDbId,
                                     targetDbPw,
                                     targetDbIp,
                                     targetDbport,
                                     targetDbName)

pg_kopo_engine = create_engine(targetUrl)

tableName = "pg_result_ys"



import d6tstack
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-988de87c625c> in <module>
#      30
#      31
# ---> 32 import d6tstack
#
# ~\anaconda3\lib\site-packages\d6tstack\__init__.py in <module>
# ----> 1 import d6tstack.combine_csv
#       2 #import d6tstack.convert_xls
#       3 import d6tstack.sniffer
#       4 #import d6tstack.sync
#       5 import d6tstack.utils
#
# ~\anaconda3\lib\site-packages\d6tstack\combine_csv.py in <module>
#       2 import pandas as pd
#       3 pd.set_option('display.expand_frame_repr', False)
# ----> 4 from scipy.stats import mode
#       5 import warnings
#       6 import ntpath, pathlib
#
# ImportError: cannot import name 'mode' from 'scipy.stats' (unknown location)
